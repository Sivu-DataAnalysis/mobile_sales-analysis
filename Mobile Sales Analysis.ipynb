# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
sales = pd.read_csv("Downloads/Data/mobile_sales_data.csv")

# %%
sales.set_index("Product",inplace=True)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50000 entries, Mobile Phone to Laptop
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Brand                    50000 non-null  object
#  1   Product Code             50000 non-null  object
#  2   Product Specification    50000 non-null  object
#  3   Price                    50000 non-null  int64
#  4   Inward Date              50000 non-null  object
#  5   Dispatch Date            50000 non-null  object
#  6   Quantity Sold            50000 non-null  int64
#  7   Customer Name            50000 non-null  object
#  8   Customer Location        50000 non-null  object
#  9   Region                   50000 non-null  object
#  10  Core Specification       25017 non-null  object
#  11  Processor Specification  50000 non-null  object
#  12  RAM                      50000 non-null  object
#  13  ROM                      50000 non-null  object
# ...

# %%
sales
# Out:
#                   Brand Product Code  \
# Product
# Mobile Phone   Motorola     88EB4558
# Laptop             Oppo     416DFEEB
# Mobile Phone    Samsung     9F975B08
# Laptop             Sony     73D2A7CC
# Laptop        Microsoft     CCE0B80D
# ...                 ...          ...
# Laptop         Motorola     8C187637
# Laptop               HP     0DA9E4D3
# Laptop          Toshiba     CAD89A93
# Mobile Phone     Lenovo     78566C17
# Laptop             Asus     9C3FC57C
#
#                                           Product Specification   Price  \
# Product
# Mobile Phone  Site candidate activity company there bit insi...   78570
# Laptop                  Beat put care fight affect address his.   44613
# Mobile Phone           Energy special low seven place audience.  159826
# Laptop        Friend record hard contain minute we role sea ...   20911
# Laptop         Program recently feeling save tree hotel people.   69832
# ...

# %%
sales.drop(columns=["Product Specification"],inplace=True)

# %%
sales
# Out:
#                   Brand Product Code   Price Inward Date Dispatch Date  \
# Product
# Mobile Phone   Motorola     88EB4558   78570  2023-08-02    2023-08-03
# Laptop             Oppo     416DFEEB   44613  2023-10-03    2023-10-06
# Mobile Phone    Samsung     9F975B08  159826  2025-03-19    2025-03-20
# Laptop             Sony     73D2A7CC   20911  2024-02-06    2024-03-27
# Laptop        Microsoft     CCE0B80D   69832  2023-08-10    2023-09-10
# ...                 ...          ...     ...         ...           ...
# Laptop         Motorola     8C187637  170385  2024-03-02    2024-04-11
# Laptop               HP     0DA9E4D3  193133  2025-01-19    2025-01-20
# Laptop          Toshiba     CAD89A93   66502  2024-01-16    2024-03-05
# Mobile Phone     Lenovo     78566C17  158883  2023-05-15    2023-05-25
# Laptop             Asus     9C3FC57C   86483  2023-08-29    2023-10-26
#
#               Quantity Sold      Customer Name      Customer Location  \
# Product
# ...

# %%
#Most expensive prdouct with its price
sales.sort_values('Price',ascending=False)
# Out:
#                 Brand Product Code   Price Inward Date Dispatch Date  \
# Product
# Mobile Phone     Asus     5F4FA6DC  199999  2024-01-25    2024-02-16
# Laptop           Vivo     83C54206  199997  2024-02-10    2024-02-20
# Mobile Phone     Dell     B6B48A95  199997  2024-09-17    2024-10-14
# Mobile Phone     iQOO     C915279A  199991  2025-03-17    2025-04-18
# Mobile Phone  OnePlus     FF19944E  199991  2023-12-03    2023-12-23
# ...               ...          ...     ...         ...           ...
# Laptop        OnePlus     A90E5948    5027  2024-02-12    2024-04-05
# Mobile Phone    Apple     7CF73D8E    5024  2024-04-09    2024-06-08
# Laptop           Asus     EF1761E8    5014  2024-05-15    2024-06-12
# Mobile Phone     Vivo     CB7ACE58    5011  2024-07-21    2024-08-03
# Mobile Phone   Huawei     1E07506F    5008  2024-10-21    2024-10-23
#
#               Quantity Sold        Customer Name  Customer Location   Region  \
# Product
# ...

# %%
#Product which was sold the most
sales["Quantity Sold"].sort_values(ascending=False).head(20)
# Out:
# Product
# Mobile Phone    10
# Laptop          10
# Laptop          10
# Laptop          10
# Mobile Phone    10
# Laptop          10
# Mobile Phone    10
# Laptop          10
# Laptop          10
# Mobile Phone    10
# Laptop          10
# Laptop          10
# Laptop          10
# Laptop          10
# Laptop          10
# Mobile Phone    10
# Laptop          10
# Laptop          10
# Laptop          10
# Mobile Phone    10
# Name: Quantity Sold, dtype: int64

# %%
#Top 10 Brands that are most expensive
sales[["Brand","Price"]].sort_values('Price',ascending=False).head(10)
# Out:
#                  Brand   Price
# Product
# Mobile Phone      Asus  199999
# Laptop            Vivo  199997
# Mobile Phone      Dell  199997
# Mobile Phone      iQOO  199991
# Mobile Phone   OnePlus  199991
# Mobile Phone     Nokia  199988
# Laptop         Toshiba  199985
# Laptop        Motorola  199984
# Mobile Phone   Toshiba  199983
# Laptop         OnePlus  199982

# %%
#Brands that have space more than 15GB
sales[sales["RAM"]>'15GB']["Brand"].value_counts()
# Out:
# Brand
# Google       2163
# Toshiba      2155
# Nokia        2150
# Sony         2133
# Redmi        2131
# OnePlus      2124
# Apple        2120
# Acer         2110
# Huawei       2101
# Samsung      2099
# Motorola     2087
# Vivo         2075
# Lenovo       2070
# iQOO         2068
# Dell         2044
# Microsoft    2044
# Oppo         2040
# HP           2024
# Asus         2012
# Realme       1955
# Name: count, dtype: int64

# %%
sales
# Out:
#                   Brand Product Code   Price Inward Date Dispatch Date  \
# Product
# Mobile Phone   Motorola     88EB4558   78570  2023-08-02    2023-08-03
# Laptop             Oppo     416DFEEB   44613  2023-10-03    2023-10-06
# Mobile Phone    Samsung     9F975B08  159826  2025-03-19    2025-03-20
# Laptop             Sony     73D2A7CC   20911  2024-02-06    2024-03-27
# Laptop        Microsoft     CCE0B80D   69832  2023-08-10    2023-09-10
# ...                 ...          ...     ...         ...           ...
# Laptop         Motorola     8C187637  170385  2024-03-02    2024-04-11
# Laptop               HP     0DA9E4D3  193133  2025-01-19    2025-01-20
# Laptop          Toshiba     CAD89A93   66502  2024-01-16    2024-03-05
# Mobile Phone     Lenovo     78566C17  158883  2023-05-15    2023-05-25
# Laptop             Asus     9C3FC57C   86483  2023-08-29    2023-10-26
#
#               Quantity Sold      Customer Name      Customer Location  \
# Product
# ...

# %%
sales.loc[["Mobile Phone"],["Core Specification"]] = 'iOS'

# %%
sales["Price per Product"]=sales["Price"]/sales["Quantity Sold"]

# %%
sales["Brand"].value_counts()

# %%
#Customers who bought laptop from South
sales[sales["Region"] == 'South']["Customer Name"].head()
# Out:
# Product
# Laptop         Larry Smith
# Laptop           Dan Kirby
# Laptop      Danielle Smith
# Laptop    Mr. James Harris
# Laptop    Megan Valenzuela
# Name: Customer Name, dtype: object

# %%
sales
# Out:
#                   Brand Product Code   Price Inward Date Dispatch Date  \
# Product
# Mobile Phone   Motorola     88EB4558   78570  2023-08-02    2023-08-03
# Laptop             Oppo     416DFEEB   44613  2023-10-03    2023-10-06
# Mobile Phone    Samsung     9F975B08  159826  2025-03-19    2025-03-20
# Laptop             Sony     73D2A7CC   20911  2024-02-06    2024-03-27
# Laptop        Microsoft     CCE0B80D   69832  2023-08-10    2023-09-10
# ...                 ...          ...     ...         ...           ...
# Laptop         Motorola     8C187637  170385  2024-03-02    2024-04-11
# Laptop               HP     0DA9E4D3  193133  2025-01-19    2025-01-20
# Laptop          Toshiba     CAD89A93   66502  2024-01-16    2024-03-05
# Mobile Phone     Lenovo     78566C17  158883  2023-05-15    2023-05-25
# Laptop             Asus     9C3FC57C   86483  2023-08-29    2023-10-26
#
#               Quantity Sold      Customer Name      Customer Location  \
# Product
# ...

# %%
sales[sales["Quantity Sold"] > 5]["Brand"].value_counts().head(10).plot(kind='barh', title="Quantity Sold")
# Out:
# <Axes: title={'center': 'Quantity Sold'}, ylabel='Brand'>

# %%
sales["SSD"].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>
